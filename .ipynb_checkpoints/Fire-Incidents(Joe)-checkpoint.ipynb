# %% [markdown]
# ## The Best neighborhood in Pittsburgh (Based on Fire Incidents)
# #### Joe Wang

# %% [markdown]
# When choosing a neighborhood, considering fire incidents is essential as they reflect the area's safety and quality of life.
#
# High fire frequencies may suggest safety risks, including outdated infrastructure or insufficient fire prevention measures. The presence of an efficient and responsive fire department is crucial for ensuring safety and protecting property. Additionally, fire incidents can influence insurance premiums, with higher rates in areas with more frequent fires.

# %%
import pandas as pd

file_path_fire_incidents = '/home/jupyter-jow188/Big-Ideas-Final-Project/FireIncidents.csv'
file_path_population = '/home/jupyter-jow188/Big-Ideas-Final-Project/Population.csv'

fire_incidents_data = pd.read_csv(file_path_fire_incidents)
population_data = pd.read_csv(file_path_population)

# %% [markdown]
# ### Introduction
# The metric we used was the ratio of the number of people in each neighborhood to the number of fire incidents. We used a dataset containing all fire incidents in Pittsburgh and a dataset containing the number of residents in all Pittsburgh neighborhoods.

# %% [markdown]
# Display the first few rows of each dataset.

# %%
fire_incidents_data.head(5), population_data.head(5)
# Out:
# (   _id     call_no  incident_type        type_description  \
#  0    1  F160029985          111.0           Building fire
#  1    2  F180022058          111.0           Building fire
#  2    3  F180022102          131.0  Passenger vehicle fire
#  3    4  F170043431          131.0  Passenger vehicle fire
#  4    5  F180021111          111.0           Building fire
#
#                                            address  alarms  \
#  0       800 BLOCK CENTER ST, WILKINSBURG PA 15221       1
#  1        1100 BLOCK JANE ST, WILKINSBURG PA 15221       1
#  2  SB STATE HWY 28 SB AT 31S, PITTSBURGH PA 15212       0
#  3      1700 BLOCK BELLEAU DR, PITTSBURGH PA 15212       0
#  4      2400 BLOCK VILLAGE RD, PITTSBURGH PA 15205       1
#
#              alarm_time primary_unit  census_tract neighborhood  \
#  0  2016-04-21T05:01:04      231EN16           NaN          NaN
#  1  2018-03-13T08:34:43      231EN16           NaN          NaN
#  2  2018-03-13T11:54:23      231EN32        2406.0          NaN
#  3  2017-05-31T08:39:47      231EN38        2509.0     Fineview
#  4  2018-03-09T10:26:42      231EN31        2808.0    Fairywood
#
#     council_district  ward         tract  public_works_division  pli_division  \
#  0               NaN   NaN  4.200356e+10                    NaN           NaN
#  1               NaN   NaN  4.200356e+10                    NaN           NaN
#  2               NaN   NaN           NaN                    NaN           NaN
#  3               6.0  25.0  4.200325e+10                    1.0          25.0
#  4               2.0  28.0  4.200356e+10                    5.0          28.0
#
#     police_zone fire_zone   latitude  longitude
#  0          NaN      3-16  40.441275 -79.882485
#  1          NaN      3-21  40.436342 -79.881003
#  2          NaN      1-1A        NaN        NaN
#  3          1.0      1-10  40.460303 -80.006980
#  4          6.0      1-16  40.449009 -80.076607  ,
#                                 Neighborhood  2010_Total_Population  \
#  0                          Allegheny Center                    933
#  1                            Allegheny West                    462
#  2                                 Allentown                   2500
#  3  Arlington - Arlington Heights (Combined)                   2113
#  4                                Banksville                   4144
#
#     2010_OneRace_Population  2010_White_Alone_Population  \
#  0                      896                          381
#  1                      448                          354
#  2                     2384                         1485
#  3                     2042                         1452
#  4                     4053                         3651
#
#     2010_Black_Alone_Population  \
#  0                          453
#  1                           84
#  2                          878
#  3                          576
#  4                          169
#
#     2010_American_Indian_and_Alaska_Native_alone_population  \
#  0                                                  4
#  1                                                  1
#  2                                                  9
#  3                                                  9
#  4                                                  2
#
#     2010_Asian_Alone_Population  \
#  0                           56
#  1                            7
#  2                            1
#  3                            3
#  4                          211
#
#     2010_Native_Hawaiian_and_Other_Pacific_Islander_alone_Population  \
#  0                                                  1
#  1                                                  0
#  2                                                  0
#  3                                                  0
#  4                                                  0
#
#     2010_Any_other_single_race_alone_Popualtion  \
#  0                                            1
#  1                                            2
#  2                                           11
#  3                                            2
#  4                                           20
#
#     2010_Population_two_or_more_races  ...  \
#  0                                 37  ...
#  1                                 14  ...
#  2                                116  ...
#  3                                 71  ...
#  4                                 91  ...
#
#     Change_2010_to_2020_Total_Population  \
#  0                                   486
#  1                                    78
#  2                                  -195
#  3                                   -73
#  4                                   -17
#
#     Change_2010_to_2020_OneRace_Population  \
#  0                                     441
#  1                                      45
#  2                                    -258
#  3                                    -153
#  4                                    -197
#
#     Change_2010_to_2020_White_Alone_Population  \
#  0                                         302
#  1                                          72
#  2                                        -213
#  3                                        -246
#  4                                        -460
#
#     Change_2010_to_2020_Black_Alone_Population  \
#  0                                         -63
#  1                                         -52
#  2                                         -93
#  3                                          44
#  4                                          25
#
#     Change_2010_to_2020_American_Indian_and_Alaska_Native_alone_population  \
#  0                                                  4
#  1                                                  0
#  2                                                 -6
#  3                                                 -4
#  4                                                  5
#
#     Change_2010_to_2020_Asian_Alone_Population  \
#  0                                         179
#  1                                           9
#  2                                          18
#  3                                           9
#  4                                         174
#
#     Change_2010_to_2020_Native_Hawaiian_and_Other_Pacific_Islander_alone_Population  \
#  0                                                  0
#  1                                                  1
#  2                                                  6
#  3                                                  0
#  4                                                  2
#
#     Change_2010_to_2020_Any_other_single_race_alone_Popualtion  \
#  0                                                 19
#  1                                                 15
#  2                                                 30
#  3                                                 44
#  4                                                 57
#
#     Change_2010_to_2020_Population_two_or_more_races  \
#  0                                                45
#  1                                                33
#  2                                                63
#  3                                                80
#  4                                               180
#
#     Change_2010_to_2020_Hispanic_or_Latino_Population
#  0                                                 23
#  1                                                 28
#  2                                                 23
#  3                                                 39
#  4                                                102
#
#  [5 rows x 31 columns])

# %% [markdown]
# Data Cleaning and Preparation. Check for missing values in both datasets and overview of missing data.

# %%
missing_values_fire = fire_incidents_data.isnull().sum()
missing_values_population = population_data.isnull().sum()

missing_values_fire, missing_values_population
# Out:
# (_id                         0
#  call_no                     0
#  incident_type              18
#  type_description            0
#  address                     0
#  alarms                      0
#  alarm_time                 18
#  primary_unit                5
#  census_tract              592
#  neighborhood             1398
#  council_district         1364
#  ward                     1399
#  tract                     851
#  public_works_division    1398
#  pli_division             1399
#  police_zone              1400
#  fire_zone                  10
#  latitude                  925
#  longitude                 925
#  dtype: int64,
#  Neighborhood                                                                       0
#  2010_Total_Population                                                              0
#  2010_OneRace_Population                                                            0
#  2010_White_Alone_Population                                                        0
#  2010_Black_Alone_Population                                                        0
#  2010_American_Indian_and_Alaska_Native_alone_population                            0
#  2010_Asian_Alone_Population                                                        0
#  2010_Native_Hawaiian_and_Other_Pacific_Islander_alone_Population                   0
#  2010_Any_other_single_race_alone_Popualtion                                        0
#  2010_Population_two_or_more_races                                                  0
#  2010_Hispanic_or_Latino_Population                                                 0
#  2020_Total_Population                                                              0
#  2020_OneRace_Population                                                            0
#  2020_White_Alone_Population                                                        0
#  2020_Black_Alone_Population                                                        0
#  2020_American_Indian_and_Alaska_Native_alone_population                            0
#  2020_Asian_Alone_Population                                                        0
#  2020_Native_Hawaiian_and_Other_Pacific_Islander_alone_Population                   0
#  2020_Any_other_single_race_alone_Popualtion                                        0
#  2020_Population_two_or_more_races                                                  0
#  2020_Hispanic_or_Latino_Population                                                 0
#  Change_2010_to_2020_Total_Population                                               0
#  Change_2010_to_2020_OneRace_Population                                             0
#  Change_2010_to_2020_White_Alone_Population                                         0
#  Change_2010_to_2020_Black_Alone_Population                                         0
#  Change_2010_to_2020_American_Indian_and_Alaska_Native_alone_population             0
#  Change_2010_to_2020_Asian_Alone_Population                                         0
#  Change_2010_to_2020_Native_Hawaiian_and_Other_Pacific_Islander_alone_Population    0
#  Change_2010_to_2020_Any_other_single_race_alone_Popualtion                         0
#  Change_2010_to_2020_Population_two_or_more_races                                   0
#  Change_2010_to_2020_Hispanic_or_Latino_Population                                  0
#  dtype: int64)

# %% [markdown]
# Clean the Fire Incidents Data. Keep only rows where both latitude and longitude are not missing and overview of the cleaned data again.

# %%
cleaned_fire_data = fire_incidents_data.dropna(subset=['latitude', 'longitude'])

cleaned_fire_data.head(), cleaned_fire_data.isnull().sum()
# Out:
# (   _id     call_no  incident_type             type_description  \
#  0    1  F160029985          111.0                Building fire
#  1    2  F180022058          111.0                Building fire
#  3    4  F170043431          131.0       Passenger vehicle fire
#  4    5  F180021111          111.0                Building fire
#  5    6  F180021782          150.0  Outside rubbish fire, Other
#
#                                         address  alarms           alarm_time  \
#  0    800 BLOCK CENTER ST, WILKINSBURG PA 15221       1  2016-04-21T05:01:04
#  1     1100 BLOCK JANE ST, WILKINSBURG PA 15221       1  2018-03-13T08:34:43
#  3   1700 BLOCK BELLEAU DR, PITTSBURGH PA 15212       0  2017-05-31T08:39:47
#  4   2400 BLOCK VILLAGE RD, PITTSBURGH PA 15205       1  2018-03-09T10:26:42
#  5  S 7TH ST & E CARSON ST, PITTSBURGH PA 15203       0  2018-03-12T09:13:28
#
#    primary_unit  census_tract      neighborhood  council_district  ward  \
#  0      231EN16           NaN               NaN               NaN   NaN
#  1      231EN16           NaN               NaN               NaN   NaN
#  3      231EN38        2509.0          Fineview               6.0  25.0
#  4      231EN31        2808.0         Fairywood               2.0  28.0
#  5      231EN24        1702.0  South Side Flats               3.0  17.0
#
#            tract  public_works_division  pli_division  police_zone fire_zone  \
#  0  4.200356e+10                    NaN           NaN          NaN      3-16
#  1  4.200356e+10                    NaN           NaN          NaN      3-21
#  3  4.200325e+10                    1.0          25.0          1.0      1-10
#  4  4.200356e+10                    5.0          28.0          6.0      1-16
#  5  4.200317e+10                    4.0          17.0          3.0       4-2
#
#      latitude  longitude
#  0  40.441275 -79.882485
#  1  40.436342 -79.881003
#  3  40.460303 -80.006980
#  4  40.449009 -80.076607
#  5  40.428618 -79.992239  ,
#  _id                        0
#  call_no                    0
#  incident_type             18
#  type_description           0
#  address                    0
#  alarms                     0
#  alarm_time                18
#  primary_unit               4
#  census_tract             507
#  neighborhood             551
#  council_district         516
#  ward                     552
#  tract                      9
#  public_works_division    551
#  pli_division             552
#  police_zone              553
#  fire_zone                  5
#  latitude                   0
#  longitude                  0
#  dtype: int64)

# %% [markdown]
# Now we insert a map for better visualization.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

plt.figure(figsize=(15, 9))
sns.scatterplot(x='longitude', y='latitude', data=cleaned_fire_data, s=15, color='red', alpha=0.8)
plt.title('Dot Map of Fire Incidents in Pittsburgh')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %% [markdown]
# The dot map above visualizes the fire incidents in Pittsburgh, with each dot representing an incident. This map provides a spatial distribution of fire incidents across the city.

# %% [markdown]
# After that, count the number of fire incidents in each neighborhood and merging this data with the population data.

# %%
# Counting the number of fire incidents in each neighborhood
fire_incidents_per_neighborhood = cleaned_fire_data['neighborhood'].value_counts().reset_index()
fire_incidents_per_neighborhood.columns = ['Neighborhood', 'Fire_Incidents']

# Merging this data with the population data
merged_data = pd.merge(fire_incidents_per_neighborhood, population_data, on='Neighborhood', how='left')

# %% [markdown]
# We use the rate of fire incidents per 1000 people in 2020 to determine which neighborhood has the lowest fire rate.

# %%
merged_data['Incidents_per_1000'] = (merged_data['Fire_Incidents'] / merged_data['2020_Total_Population']) * 1000

sorted_data = merged_data.sort_values(by='Incidents_per_1000', ascending=False)

final_data = sorted_data[['Neighborhood', 'Fire_Incidents', '2020_Total_Population', 'Incidents_per_1000']]

final_data
# Out:
#                  Neighborhood  Fire_Incidents  2020_Total_Population  \
# 63                    Chateau              41                   19.0
# 73                South Shore              23                   29.0
# 46                North Shore              63                  301.0
# 76                   West End              22                  205.0
# 50              Homewood West              59                  642.0
# ..                        ...             ...                    ...
# 1   Central Business District             263                    NaN
# 34      Spring Hill-City View             101                    NaN
# 57                  Arlington              51                    NaN
# 84          Arlington Heights              13                    NaN
# 90       Mount Oliver Borough               6                    NaN
#
#     Incidents_per_1000
# 63         2157.894737
# 73          793.103448
# 46          209.302326
# 76          107.317073
# 50           91.900312
# ..                 ...
# 1                  NaN
# 34                 NaN
# 57                 NaN
# 84                 NaN
# 90                 NaN
#
# [91 rows x 4 columns]

# %% [markdown]
# Sort the data by the rate of incidents per 1000, from lowest to highest, only display top 10.

# %%
sorted_data_ascending = final_data.sort_values(by='Incidents_per_1000', ascending=True)

sorted_data_ascending.head(10)
# Out:
#            Neighborhood  Fire_Incidents  2020_Total_Population  \
# 69             Westwood              27                 3332.0
# 89        Regent Square               9                  971.0
# 67          Morningside              32                 3252.0
# 21  Squirrel Hill North             130                11879.0
# 82       Swisshelm Park              15                 1339.0
# 25        North Oakland             124                10691.0
# 10            Shadyside             181                15317.0
# 41        Highland Park              76                 6235.0
# 85              Oakwood              13                 1025.0
# 53      Stanton Heights              57                 4427.0
#
#     Incidents_per_1000
# 69            8.103241
# 89            9.268795
# 67            9.840098
# 21           10.943682
# 82           11.202390
# 25           11.598541
# 10           11.816935
# 41           12.189254
# 85           12.682927
# 53           12.875536

# %% [markdown]
# ### Conclusion

# %%
# Selecting the last 10 results (lowest fire rate neighborhoods) for the histogram
lowest_fire_rate_neighborhoods = sorted_data_ascending.head(10)

# Creating a histogram
plt.figure(figsize=(12, 6))
sns.barplot(x='Neighborhood', y='Incidents_per_1000', data=lowest_fire_rate_neighborhoods)
plt.title('Top 10 Neighborhoods with the Lowest Fire Incident Rates in Pittsburgh')
plt.xlabel('Neighborhood')
plt.ylabel('Fire Incidents per 1000 People')
plt.xticks(rotation=45)
plt.show()
